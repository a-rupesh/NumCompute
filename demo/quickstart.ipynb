0 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.9 MB 4.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.6/12.9 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.9 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.9 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.9 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.9 MB 4.3 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.9 MB 4.3 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.9 MB 4.3 MB/s eta 0:00:01
#      ---------------------------------------  12.9/12.9 MB 4.2 MB/s eta 0:00:01
#      ---------------------------------------- 12.9/12.9 MB 4.1 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.2.6
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\Aakash\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Obtaining file:///C:/Users/Aakash/Downloads/Documents/Adelaide%20University/Semester%201/Programming%20in%20AI
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\aakash\appdata\local\programs\python\python310\lib\site-packages (from numcompute==0.1.0) (2.2.6)
# Building wheels for collected packages: numcompute
#   Building editable for numcompute (pyproject.toml): started
#   Building editable for numcompute (pyproject.toml): finished with status 'done'
#   Created wheel for numcompute: filename=numcompute-0.1.0-0.editable-py3-none-any.whl size=3779 sha256=f03899f9bf50fc1408e5e79f50f63fdee8889a8b4544a54e36b37d4eae91f35d
#   Stored in directory: C:\Users\Aakash\AppData\Local\Temp\pip-ephem-wheel-cache-mn3btd_n\wheels\ab\89\ea\52ad67edafd782f821561de3599c59f5160b75593390ac6953
# Successfully built numcompute
# Installing collected packages: numcompute
# Successfully installed numcompute-0.1.0
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Imports

# %%
import numpy as np
import tempfile
from pathlib import Path

from numcompute.io import load_csv
from numcompute.preprocessing import StandardScaler, SimpleImputer, OneHotEncoder
from numcompute.sort_search import top_k, quickselect, binary_search
from numcompute.rank import rank, percentile
from numcompute.stats import mean, std, histogram, quantile
from numcompute.metrics import accuracy, precision, recall, f1, confusion_matrix, mse
from numcompute.optim import grad, jacobian
from numcompute.pipeline import Pipeline
from numcompute.benchmarking import (
    compare_functions,
    vectorized_sum_of_squares,
    loop_sum_of_squares,
    format_benchmark_table,
)

# %% [markdown]
# CSV loading with missing values

# %%
csv_text = "1,10,\n2,,0\n3,30,1\n4,40,0"

with tempfile.NamedTemporaryFile(mode="w+", suffix=".csv", delete=False) as f:
    f.write(csv_text)
    temp_path = f.name

X_raw = load_csv(temp_path, delimiter=",")
print("Loaded CSV:")
print(X_raw)
# Out:
# Loaded CSV:
# [[ 1. 10. nan]
#  [ 2. nan  0.]
#  [ 3. 30.  1.]
#  [ 4. 40.  0.]]

# %% [markdown]
# Preprocessing

# %%
X_num = X_raw[:, :2]
y = X_raw[:, 2]

imputer = SimpleImputer(strategy="mean")
X_imputed = imputer.fit_transform(X_num)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

print("Imputed data:")
print(X_imputed)
print("\nScaled data:")
print(X_scaled)
# Out:
# Imputed data:
# [[ 1.         10.        ]
#  [ 2.         26.66666667]
#  [ 3.         30.        ]
#  [ 4.         40.        ]]
#
# Scaled data:
# [[-1.34164079 -1.5430335 ]
#  [-0.4472136   0.        ]
#  [ 0.4472136   0.3086067 ]
#  [ 1.34164079  1.2344268 ]]

# %% [markdown]
# One-hot Encoding

# %%
X_cat = np.array([["A"], ["B"], ["A"], ["C"]])
encoder = OneHotEncoder()
X_encoded = encoder.fit_transform(X_cat)

print("One-hot encoded:")
print(X_encoded)
# Out:
# One-hot encoded:
# [[1 0 0]
#  [0 1 0]
#  [1 0 0]
#  [0 0 1]]

# %% [markdown]
# Sort/Search and Rank

# %%
values = np.array([10, 30, 20, 20, 50, 40])

print("Top-3 largest:")
print(top_k(values, k=3, largest=True, return_indices=False))

print("\nQuickselect k=2 (3rd smallest):")
print(quickselect(values, 2))

sorted_vals = np.sort(values)
print("\nSorted values:")
print(sorted_vals)

print("\nBinary search for 30:")
print(binary_search(sorted_vals, 30))

print("\nRanks (average ties):")
print(rank(values, method="average"))

print("\nPercentile 75:")
print(percentile(values, 75))
# Out:
# Top-3 largest:
# [50 40 30]
#
# Quickselect k=2 (3rd smallest):
# 20
#
# Sorted values:
# [10 20 20 30 40 50]
#
# Binary search for 30:
# (3, True)
#
# Ranks (average ties):
# [1.  4.  2.5 2.5 6.  5. ]
#
# Percentile 75:
# 37.5

# %% [markdown]
# Statistics

# %%
print("Mean:", mean(values))
print("Std:", std(values))
print("Quantile 0.5:", quantile(values, 0.5))

counts, bins = histogram(values, bins=4)
print("\nHistogram counts:", counts)
print("Histogram bins:", bins)
# Out:
# Mean: 28.333333333333332
# Std: 13.437096247164249
# Quantile 0.5: 25.0
#
# Histogram counts: [1 2 1 2]
# Histogram bins: [10. 20. 30. 40. 50.]

# %% [markdown]
# Metrics

# %%
y_true = np.array([0, 1, 1, 0, 1])
y_pred = np.array([0, 1, 0, 0, 1])

print("Accuracy:", accuracy(y_true, y_pred))
print("Precision:", precision(y_true, y_pred))
print("Recall:", recall(y_true, y_pred))
print("F1:", f1(y_true, y_pred))
print("Confusion matrix:")
print(confusion_matrix(y_true, y_pred))

y_true_reg = np.array([1.0, 2.0, 3.0])
y_pred_reg = np.array([1.2, 1.9, 2.8])
print("MSE:", mse(y_true_reg, y_pred_reg))
# Out:
# Accuracy: 0.8
# Precision: 1.0
# Recall: 0.6666666666666666
# F1: 0.8
# Confusion matrix:
# [[2 0]
#  [1 2]]
# MSE: 0.030000000000000023

# %% [markdown]
# Gradient and Jacobian

# %%
def f(x):
    return x[0] ** 2 + x[1] ** 2

def F(x):
    return np.array([
        x[0] + x[1],
        x[0] * x[1],
    ])

x = np.array([3.0, 4.0])

print("Gradient:", grad(f, x))
print("Jacobian:")
print(jacobian(F, x))
# Out:
# Gradient: [6. 8.]
# Jacobian:
# [[1. 1.]
#  [4. 3.]]

# %% [markdown]
# Pipeline Demo

# %%
class DummyModel:
    def fit(self, X, y=None):
        self.threshold_ = np.mean(X[:, 0])
        return self

    def predict(self, X):
        return (X[:, 0] > self.threshold_).astype(int)

pipe = Pipeline([
    ("imputer", SimpleImputer(strategy="mean")),
    ("scaler", StandardScaler()),
    ("model", DummyModel()),
])

pipe.fit(X_num, y=np.array([0, 0, 1, 1]))
preds = pipe.predict(X_num)

print("Pipeline predictions:")
print(preds)
# Out:
# Pipeline predictions:
# [0 0 1 1]

# %% [markdown]
# Benchmark Table

# %%
x = np.random.rand(1_000_000)

result = compare_functions(
    vectorized_sum_of_squares,
    loop_sum_of_squares,
    x,
    repeat=5,
    warmup=1,
)

print(format_benchmark_table([result["first"], result["second"]]))
print("Speedup:", f"{result['speedup_vs_slow']:.2f}x")
# Out:
# name                      | mean_time    | median_time  | min_time     | max_time     | std_time
# --------------------------+--------------+--------------+--------------+--------------+-------------
# vectorized_sum_of_squares | 4.437060e-03 | 3.950700e-03 | 3.140300e-03 | 6.457100e-03 | 1.210804e-03
# loop_sum_of_squares       | 2.120439e-01 | 2.154664e-01 | 1.958034e-01 | 2.256438e-01 | 1.055008e-02
# Speedup: 47.79x
